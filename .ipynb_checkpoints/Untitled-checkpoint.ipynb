# %%
import pandas as pd

# Load a dataset (example)
df = pd.read_csv(r"C:\Users\CTrader\Desktop\3 rd year\CI\DP\DataPreprocessing\smartshine_carwash_messy_data.csv")

# Show top rows
df.head()
# Out:
#   customer_id service_date vehicle_type        service_type      service_cost  \
# 0       C0440   2024-02-25       luxury  Interior Detailing  498.851294654011
# 1       C0603   06-09-2021        truck         deluxe wash             65.41
# 2       C0230   2022-09-26          NaN        PREMIUM WASH             35.33
# 3       C0050   2021-05-22          NaN          basic wash              21.9
# 4       C0646   2021-08-12          Van         deluxe wash             57.74
#
#    service_duration  customer_rating payment_method  location record_source
# 0              66.0              6.0    credit card  Suburban           Web
# 1              49.0              3.0     debit card   Highway     in-person
# 2              31.0              NaN     Mobile Pay   highway           WEB
# 3              23.0              NaN     Debit Card   AIRPORT        MOBILE
# 4              48.0              3.0     MOBILE PAY   Highway     In-Person

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

df = pd.read_csv(r"C:\Users\CTrader\Desktop\3 rd year\CI\DP\DataPreprocessing\smartshine_carwash_messy_data.csv")

missing_before = df.isna().sum()
missing_before[missing_before > 0].plot(kind='bar', figsize=(8,4), color='red')
plt.title("Before Cleaning – Missing Values per Column")
plt.ylabel("Count of Missing Entries")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,4))
sns.heatmap(df.head(50).isna(), cbar=False, cmap='Reds')
plt.title("Before Cleaning – Missing Value Pattern (First 50 Rows)")
plt.show()
